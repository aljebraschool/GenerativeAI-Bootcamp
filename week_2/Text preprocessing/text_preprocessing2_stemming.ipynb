# %% [markdown]
# ## Text Preprocessing for Machine Learning - Stemming

# %% [markdown]
# Stemming is the process of reducing a word to its base or root form by chopping off the end (and sometimes the beginning) of the word.
#
# The goal is to group together different forms of the same word, even if the root isn't a real word itself.

# %% [markdown]
# Simple Analogy:
#    Think of a gardener trimming a bush back to its main stems. They cut off the branches and leaves (the suffixes and prefixes) to get to the core structure.
#
# Key Point:
#     Stemming is a crude but fast method. It often creates roots that are not actual words.
#
# Examples:
#
# - running → run
#
# - happily → happili (Note: this isn't a real word, but it's the stem)
#
# - cats → cat
#
# - argued, arguing, argues → argu

# %% [markdown]
# Why it's used:
#
# Its main purpose is in search engines and text analysis.
#
# If you search for "running," stemming helps the engine also return results for "run" and "ran," because they all reduce to the same root.

# %% [markdown]
# ## Stemming code Implementation

# %%
words = ["eating","eats","eaten","writing","writes","programming","programs","history","finally","finalized"]

# %% [markdown]
# ### PorterStemmer

# %%
from nltk.stem import PorterStemmer

stemming=PorterStemmer()

for word in words:
    print(word+"---->"+stemming.stem(word))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from nltk.stem import PorterStemmer
#       3 stemming=PorterStemmer()
#       5 for word in words:
#
# File ~/.local/lib/python3.10/site-packages/nltk/__init__.py:134
#     126     subprocess.Popen = _fake_Popen
#     128 ###########################################################
#     129 # TOP-LEVEL MODULES
#     130 ###########################################################
#     131
#     132 # Import top-level functionality into top-level namespace
# --> 134 from nltk.collocations import *
#     135 from nltk.decorators import decorator, memoize
#     136 from nltk.featstruct import *
#
# File ~/.local/lib/python3.10/site-packages/nltk/collocations.py:36
#      33 import itertools as _itertools
#      35 # these two unused imports are referenced in collocations.doctest
# ---> 36 from nltk.metrics import (
#      37     BigramAssocMeasures,
#      38     ContingencyMeasures,
#      39     QuadgramAssocMeasures,
#      40     TrigramAssocMeasures,
#      41 )
#      42 from nltk.metrics.spearman import ranks_from_scores, spearman_correlation
#      43 from nltk.probability import FreqDist
#
# File ~/.local/lib/python3.10/site-packages/nltk/metrics/__init__.py:17
#      10 """
#      11 NLTK Metrics
#      12
#      13 Classes and methods for scoring processing modules.
#      14 """
#      16 from nltk.metrics.agreement import AnnotationTask
# ---> 17 from nltk.metrics.aline import align
#      18 from nltk.metrics.association import (
#      19     BigramAssocMeasures,
#      20     ContingencyMeasures,
#    (...)
#      23     TrigramAssocMeasures,
#      24 )
#      25 from nltk.metrics.confusionmatrix import ConfusionMatrix
#
# File ~/.local/lib/python3.10/site-packages/nltk/metrics/aline.py:41
#       9 """
#      10 ALINE
#      11 https://webdocs.cs.ualberta.ca/~kondrak/
#    (...)
#      37 University of Toronto.
#      38 """
#      40 try:
# ---> 41     import numpy as np
#      42 except ImportError:
#      43     np = None
#
# File ~/.local/lib/python3.10/site-packages/numpy/__init__.py:114
#     111 from . import _distributor_init
#     113 try:
# --> 114     from numpy.__config__ import show_config
#     115 except ImportError as e:
#     116     msg = """Error importing numpy: you should not try to import numpy from
#     117     its source directory; please exit the numpy source tree, and relaunch
#     118     your python interpreter from there."""
#
# File ~/.local/lib/python3.10/site-packages/numpy/__config__.py:4
#       1 # This file is generated by numpy's build process
#       2 # It contains system_info results at the time of building this package.
#       3 from enum import Enum
# ----> 4 from numpy._core._multiarray_umath import (
#       5     __cpu_features__,
#       6     __cpu_baseline__,
#       7     __cpu_dispatch__,
#       8 )
#      10 __all__ = ["show_config"]
#      11 _built_with_meson = True
#
# File ~/.local/lib/python3.10/site-packages/numpy/_core/__init__.py:23
#      20         env_added.append(envkey)
#      22 try:
# ---> 23     from . import multiarray
#      24 except ImportError as exc:
#      25     import sys
#
# File ~/.local/lib/python3.10/site-packages/numpy/_core/multiarray.py:10
#       1 """
#       2 Create the numpy._core.multiarray namespace for backward compatibility.
#       3 In v1.16 the multiarray and umath c-extension modules were merged into
#    (...)
#       6
#       7 """
#       9 import functools
# ---> 10 from . import overrides
#      11 from . import _multiarray_umath
#      12 from ._multiarray_umath import *  # noqa: F403
#
# File ~/.local/lib/python3.10/site-packages/numpy/_core/overrides.py:7
#       5 from .._utils import set_module
#       6 from .._utils._inspect import getargspec
# ----> 7 from numpy._core._multiarray_umath import (
#       8     add_docstring,  _get_implementing_args, _ArrayFunctionDispatcher)
#      11 ARRAY_FUNCTIONS = set()
#      13 array_function_like_doc = (
#      14     """like : array_like, optional
#      15         Reference object to allow the creation of arrays which are not
#    (...)
#      19         compatible with that passed in via this argument."""
#      20 )
#
# RuntimeError: CPU dispatcher tracer already initlized

# %%
stemming.stem('congratulations')
# Out:
# 'congratul'

# %%
stemming.stem("sitting")
# Out:
# 'sit'

# %% [markdown]
# ### Snowball Stemmer
#
# It is a stemming algorithm which is also known as the Porter2 stemming algorithm as
#
# it is a better version of the Porter Stemmer since some issues of it were fixed in this stemmer.

# %%
from nltk.stem import SnowballStemmer

snowballsstemmer=SnowballStemmer('english')

for word in words:
    print(word+"---->"+snowballsstemmer.stem(word))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from nltk.stem import SnowballStemmer
#       3 snowballsstemmer=SnowballStemmer('english')
#       5 for word in words:
#
# File ~/.local/lib/python3.10/site-packages/nltk/__init__.py:134
#     126     subprocess.Popen = _fake_Popen
#     128 ###########################################################
#     129 # TOP-LEVEL MODULES
#     130 ###########################################################
#     131
#     132 # Import top-level functionality into top-level namespace
# --> 134 from nltk.collocations import *
#     135 from nltk.decorators import decorator, memoize
#     136 from nltk.featstruct import *
#
# File ~/.local/lib/python3.10/site-packages/nltk/collocations.py:36
#      33 import itertools as _itertools
#      35 # these two unused imports are referenced in collocations.doctest
# ---> 36 from nltk.metrics import (
#      37     BigramAssocMeasures,
#      38     ContingencyMeasures,
#      39     QuadgramAssocMeasures,
#      40     TrigramAssocMeasures,
#      41 )
#      42 from nltk.metrics.spearman import ranks_from_scores, spearman_correlation
#      43 from nltk.probability import FreqDist
#
# File ~/.local/lib/python3.10/site-packages/nltk/metrics/__init__.py:17
#      10 """
#      11 NLTK Metrics
#      12
#      13 Classes and methods for scoring processing modules.
#      14 """
#      16 from nltk.metrics.agreement import AnnotationTask
# ---> 17 from nltk.metrics.aline import align
#      18 from nltk.metrics.association import (
#      19     BigramAssocMeasures,
#      20     ContingencyMeasures,
#    (...)
#      23     TrigramAssocMeasures,
#      24 )
#      25 from nltk.metrics.confusionmatrix import ConfusionMatrix
#
# File ~/.local/lib/python3.10/site-packages/nltk/metrics/aline.py:41
#       9 """
#      10 ALINE
#      11 https://webdocs.cs.ualberta.ca/~kondrak/
#    (...)
#      37 University of Toronto.
#      38 """
#      40 try:
# ---> 41     import numpy as np
#      42 except ImportError:
#      43     np = None
#
# File ~/.local/lib/python3.10/site-packages/numpy/__init__.py:114
#     111 from . import _distributor_init
#     113 try:
# --> 114     from numpy.__config__ import show_config
#     115 except ImportError as e:
#     116     msg = """Error importing numpy: you should not try to import numpy from
#     117     its source directory; please exit the numpy source tree, and relaunch
#     118     your python interpreter from there."""
#
# File ~/.local/lib/python3.10/site-packages/numpy/__config__.py:4
#       1 # This file is generated by numpy's build process
#       2 # It contains system_info results at the time of building this package.
#       3 from enum import Enum
# ----> 4 from numpy._core._multiarray_umath import (
#       5     __cpu_features__,
#       6     __cpu_baseline__,
#       7     __cpu_dispatch__,
#       8 )
#      10 __all__ = ["show_config"]
#      11 _built_with_meson = True
#
# File ~/.local/lib/python3.10/site-packages/numpy/_core/__init__.py:23
#      20         env_added.append(envkey)
#      22 try:
# ---> 23     from . import multiarray
#      24 except ImportError as exc:
#      25     import sys
#
# File ~/.local/lib/python3.10/site-packages/numpy/_core/multiarray.py:10
#       1 """
#       2 Create the numpy._core.multiarray namespace for backward compatibility.
#       3 In v1.16 the multiarray and umath c-extension modules were merged into
#    (...)
#       6
#       7 """
#       9 import functools
# ---> 10 from . import overrides
#      11 from . import _multiarray_umath
#      12 from ._multiarray_umath import *  # noqa: F403
#
# File ~/.local/lib/python3.10/site-packages/numpy/_core/overrides.py:7
#       5 from .._utils import set_module
#       6 from .._utils._inspect import getargspec
# ----> 7 from numpy._core._multiarray_umath import (
#       8     add_docstring,  _get_implementing_args, _ArrayFunctionDispatcher)
#      11 ARRAY_FUNCTIONS = set()
#      13 array_function_like_doc = (
#      14     """like : array_like, optional
#      15         Reference object to allow the creation of arrays which are not
#    (...)
#      19         compatible with that passed in via this argument."""
#      20 )
#
# RuntimeError: CPU dispatcher tracer already initlized

# %%
stemming.stem("fairly")
# Out:
# 'fairli'

# %%
stemming.stem("sportingly")
# Out:
# 'sportingli'

# %%
snowballsstemmer.stem("fairly")
# Out:
# 'fair'

# %%
snowballsstemmer.stem("sportingly")
# Out:
# 'sport'

# %%
snowballsstemmer.stem('goes')
# Out:
# 'goe'

# %%
stemming.stem('goes')
# Out:
# 'goe'
