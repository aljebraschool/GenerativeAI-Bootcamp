# %% [markdown]
# ## Feature Engineering for Machine Learning - Term Frequency-Inverse Document Frequency (TF-IDF)

# %% [markdown]
# TF-IDF (Term Frequency-Inverse Document Frequency) is a numerical statistic that measures how important a word is to a document within a collection of documents.
#
# It weights words by both how often they appear in a specific document AND how rare they are across all documents.
#
# Think of it as a smart scoring system that identifies words that are both:
#
# - Frequent in a particular document (common locally)
#
# - Rare in other documents (unique globally)

# %% [markdown]
# Simple Analogy:
# Imagine you're analyzing book reviews. The word "book" appears in every review (not unique), but "terrible" appears frequently in negative reviews and rarely in positive ones. TF-IDF gives "terrible" a high score in negative reviews because it's both frequent there and rare elsewhere.
#
# The Two Components:
#
# 1. Term Frequency (TF): How often a word appears in a specific document
#
# - "amazing" appears 5 times in Review A
#
# - Higher TF = more relevant to that document
#
# 2. Inverse Document Frequency (IDF): How rare the word is across all documents
#
# - "amazing" appears in only 2% of all reviews
#
# - Higher IDF = more unique/important word
#
# TF-IDF = TF × IDF

# %% [markdown]
# Key Point:
#
# TF-IDF automatically discounts common words (like "the", "and") that appear everywhere,
#
# while highlighting words that are characteristic of specific documents.
#
# Example:
#
# In a collection of movie reviews:
#
# - Word: "cinematography"
#
#     - High TF in reviews about visually stunning films
#
#     - High IDF because it rarely appears in other reviews
#
#     - Result: High TF-IDF score - this word is very important for identifying reviews about visual quality
#
# - Word: "movie"
#
#     - High TF in many reviews
#
#     - Very low IDF because it appears in almost every review
#
#     - Result: Low TF-IDF score - this word is not distinctive

# %% [markdown]
# Why it's used:
#
# Its purpose is to identify the most meaningful words in documents. It's crucial for:
#
# - Search Engines: Ranking search results by relevance
#
# - Document Classification: Identifying key features that distinguish categories
#
# - Information Retrieval: Finding the most important terms in large text collections
#
# - Text Summarization: Extracting key phrases from documents
#
# TF-IDF is essentially a refined version of Bag of Words that understands some words are more important than others.

# %% [markdown]
# ## TF-IDF code Implementation

# %%
import pandas as pd

# %%
train_data = pd.read_csv('(bow)labeledTrainData.csv', header=0, delimiter="\t", quoting=3)

# %%
train_data.shape
# Out:
# (25000, 3)

# %%
train_data.head()
# Out:
#          id  sentiment                                             review
# 0  "5814_8"          1  "With all this stuff going down at the moment ...
# 1  "2381_9"          1  "\"The Classic War of the Worlds\" by Timothy ...
# 2  "7759_3"          0  "The film starts with a manager (Nicholas Bell...
# 3  "3630_4"          0  "It must be assumed that those who praised thi...
# 4  "9495_8"          1  "Superbly trashy and wondrously unpretentious ...

# %% [markdown]
# ### Data cleaning and preprocessing

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/aljebra/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Define the fraction of the dataset to use (e.g., 10%)
fraction = 0.10 

# Calculate the number of rows to use
num_rows = int(len(train_data) * fraction)

# Select a random sample of rows
train_data = train_data.sample(n=num_rows, random_state=42)

# %%
lematization = WordNetLemmatizer()

# %%
processed_word = []

for sentence in train_data.index:
    review = re.sub('[^a-zA-Z]', " ", train_data.loc[sentence, 'review'])
    review = review.split()
    lemmatized_word = [lematization.lemmatize(word.lower()) for word in review if word not in stopwords.words('english')]
    processed_word.append(" ".join(lemmatized_word))

# %%
processed_word[:10]
# Out:
# ['i read there girl my soup came peter seller low period watching movie i surprised almost nothing happens movie seemingly presence seller goldie hawn help movie the whole movie seems like randomly filmed whatever happened without scripting anything maybe i seen every movie middle aged elderly people trying hippy one give movie pretty bad name br br all seller hawn starred much better movie waste time pretty worthless',
#  'this film pull get go grab attention acknowledging yeah story opening clich funeral br br in hand judi i given material done the great reunion famous pick one please team army platoon theatre group singer band br br but movie never stoop cheap sentimentalization think going swoop another direction a case point flower sent admirer judi br br the band member interesting group ride clich one jail one found religion one alkie one sunk dementia but joie de vivre rediscovered judi ignited granddaughter interest carry u along make u overlook sometimes simplistic nature plot br br the cast talent leslie caron incomparable jazzist cleo laine amazing high note last performance joan sims brava joan cute button flirtatious ian holm ball olympia dukakis money grabbing divorc e living highland scotland ghillie whiskey the closing scene standard hollywoodland fare judgmental child star converted fun loving supporter old lover reunited youngster swept old timer music life simple but i would watch intend granddaughter for right hand sometimes one love brazen old clich',
#  'from awful death scene gun fire without making sound character called fiend it tiresome slow moving unimaginative drivel it ok seeing guy cape hunchback lurking around visually creepy probably occupied moviegoer time even one would think would little imagination verisimilitude even film like i kept waiting something happen importance people stood around making speech acting like posing office picnic and bullet previous commentator mentioned perhaps best clue would search water spot someone pant pocket',
#  'i saw movie day ago this movie great make feel want something really bad always dreamed this show big wish come true trought happiness sadness hopeless failure but strong enough heart really belongs something love make thing different happy',
#  'for film much promise disappointing thinly plotted acting ranging horrendous unbelievable the plot hole swiss cheese worst clich ending i seen movie time the final scene would ripped heart entire movie painful begin i numb from first scene one left wondering sister trying reach twin help simply scare death would better audience saved u two hour worst acting i seen date it horror true sense word',
#  'i caught bit concert public television knew i the boy give everyone royal albert excellent often thrilling performance complete every way pure synth smoke shrouded laser strobe grandiose entrance unstoned serious appreciative audience left bottle rocket home br br if cream fan heard blue fan rock n roll fan disappointed view listen dvd you also never lose dvd never lend anyone this dvd justifies selfishness tell get it good replayable want keep within easy reach',
#  'comment like comment necessary we talking time masterpiece season generation this type movie still patience watch in like disney movie kind magic all character way alive real easy understand message even understand language like understood first watched movie six year old maybe english good learned know mostly kind movie one great dimension kind movie present time rare but one big shame in country impossible watch disney movie we copyright child disabled enjoy learn kind movie so watch movie once upon dream',
#  'i loved original it brilliant always strangely though i actually looked forward seeing make i usually little bit make far many somehow intrigued i really enjoying begin caine brilliant usual jude law managing hold next it quite clever modernised working what stop really good last seven minute it go completely away original far fact cease clever get annoying the end original fantastic so much tension built unbelievably clever this it grows tension frustration seemed decided make caine character homosexual it trying far hard different and bang law dead roll credit this film worth watch simply performance last seven minute really drag what pity',
#  'hmm imdb rating good comment bla bla okay two friend orderd pizza sat wanted see something cool ichi least something brainless funny like versus but naked blood sucked it complete waste okay scene woman like eat quite outstanding but nothing nothing less i summerize plot people already i wanted stop hype but watch rate maybe push rating sould one thing come mind soundtrack even worse carpenter ever okay john cool',
#  'here be spoiler br br recap mia helin returning home capital stockholm rural r ttvik celebrate father th birthday she far youngest child two sister eivor ernst gunilla petr n eivor family still life r ttvik gunilla divorced moved town away mia still single focused career there lot jealousy almost animosity sister conflict arise around confront personal problem difficult handle a party go alcohol consumed secret become unveiled conflict arise br br comment to work new writer director disappointing see movie follow exact track older swedish comedy drama following year there really new element idea this movie draw upon three basic area embarrassing humor based character making fool sorrow anxiety this move focus last one almost forgetting first point movie go along no loss though since humor funny the performance cast good i guess though lost behind anguish soon forgotten i hope would new idea influence none to conclude better way spend one time watching br br']

# %%
vectorizer = TfidfVectorizer(max_features=100)

# %%
X = vectorizer.fit_transform(processed_word).toarray()
