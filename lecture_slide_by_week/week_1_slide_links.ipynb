# %% [markdown]
# [Week 1: Setting Up Your AI Development Environment & Python Foundations for AI](https://www.canva.com/design/DAG4v3erp64/QmixyCMVkpB0aM2iLM6hbQ/edit?utm_content=DAG4v3erp64&utm_campaign=designshare&utm_medium=link2&utm_source=sharebutton)

# %% [markdown]
# [Basic Python programming](https://colab.research.google.com/drive/18VdxpaM2fJvcl3cxBowiYuHf_deH3etR?usp=sharing)
