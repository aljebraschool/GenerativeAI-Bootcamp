# %%
import torch
print(torch.__version__)             # Should show 2.3.1
print(torch.cuda.is_available())     # Should be "True"
print(torch.cuda.get_device_name(0)) # Should show "GeForce GTX 1650"
# Out:
# 2.5.1+cu121
# True
# NVIDIA GeForce GTX 1650 with Max-Q Design

# %%
from dotenv import load_dotenv
import os

# %%
load_dotenv()
# Out:
# True

# %%
api_key = os.getenv("HF_TOKEN")

# %%
from langchain_huggingface import HuggingFaceEmbeddings

# %%
embeddings = HuggingFaceEmbeddings(model_name='all-MiniLM-L6-v2')

# %%
text = "This is a text document"

query_result = embeddings.embed_query(text)

query_result
# Out:
# [-0.05052422359585762,
#  0.13963381946086884,
#  -0.021229136735200882,
#  0.020714713260531425,
#  0.011736690066754818,
#  0.018851736560463905,
#  -0.001095350249670446,
#  0.0501369945704937,
#  0.060743484646081924,
#  0.03445146232843399,
#  0.035449475049972534,
#  0.08333560824394226,
#  0.0016957870684564114,
#  -0.01998325251042843,
#  -0.08711870014667511,
#  0.01406007818877697,
#  -0.035323385149240494,
#  -0.03419909626245499,
#  0.007069721817970276,
#  0.03230580314993858,
#  0.03686535358428955,
#  0.12151571363210678,
#  0.026585308834910393,
#  -0.003561505815014243,
#  -0.004082300700247288,
#  0.10315396636724472,
#  -0.0964757576584816,
#  0.029928073287010193,
#  0.05651237070560455,
#  -0.014492420479655266,
#  -0.006630097981542349,
#  0.05771530419588089,
#  0.13242638111114502,
#  0.04063958674669266,
#  0.02638828568160534,
#  0.013577685691416264,
#  0.011662902310490608,
#  0.014348835684359074,
#  0.01821017637848854,
#  0.037134602665901184,
# ...

# %%
#also for document which will contain list of item or string 
doc_result = embeddings.embed_documents([text, "This is not a document "])

doc_result[0]
# Out:
# [-0.050524234771728516,
#  0.13963381946086884,
#  -0.02122914046049118,
#  0.02071470580995083,
#  0.011736679822206497,
#  0.01885172165930271,
#  -0.0010953593300655484,
#  0.050137005746364594,
#  0.060743462294340134,
#  0.03445146232843399,
#  0.03544948250055313,
#  0.08333560079336166,
#  0.0016957910265773535,
#  -0.01998324505984783,
#  -0.0871187224984169,
#  0.01406006794422865,
#  -0.0353233739733696,
#  -0.03419911488890648,
#  0.007069744635373354,
#  0.03230580314993858,
#  0.036865342408418655,
#  0.12151569128036499,
#  0.026585295796394348,
#  -0.003561505116522312,
#  -0.004082292318344116,
#  0.10315395891666412,
#  -0.096475750207901,
#  0.029928062111139297,
#  0.05651238188147545,
#  -0.014492440968751907,
#  -0.006630107294768095,
#  0.05771530419588089,
#  0.1324264109134674,
#  0.04063957929611206,
#  0.026388276368379593,
#  0.013577683828771114,
#  0.011662899516522884,
#  0.014348825439810753,
#  0.018210170790553093,
#  0.03713461756706238,
# ...
