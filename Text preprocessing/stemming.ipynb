# %%
words = ["eating","eats","eaten","writing","writes","programming","programs","history","finally","finalized"]

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

# %%
for word in words:
    print(f"word : {word}----> stemmedword: {stemmer.stem(word)}")
# Out:
# word : eating----> stemmedword: eat
# word : eats----> stemmedword: eat
# word : eaten----> stemmedword: eaten
# word : writing----> stemmedword: write
# word : writes----> stemmedword: write
# word : programming----> stemmedword: program
# word : programs----> stemmedword: program
# word : history----> stemmedword: histori
# word : finally----> stemmedword: final
# word : finalized----> stemmedword: final

# %%
words = ["मेरा ", "नाम" , "मनसा है।"]

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

# %%
for word in words:
    print(f"word : {word}----> stemmedword: {stemmer.stem(word)}")
# Out:
# word : मेरा ----> stemmedword: मेरा
# word : नाम----> stemmedword: नाम
# word : मनसा है।----> stemmedword: मनसा है।

# %%
from nltk.stem import SnowballStemmer

stemmer = SnowballStemmer('english')

# %%
for word in words:
    print(f"word : {word}----> stemmedword: {stemmer.stem(word)}")
# Out:
# word : मेरा ----> stemmedword: मेरा
# word : नाम----> stemmedword: नाम
# word : मनसा है।----> stemmedword: मनसा है।
