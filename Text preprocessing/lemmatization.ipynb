# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /home/aljebra/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer

lemma = WordNetLemmatizer()

# %%
words = ["eats", 'eaten', 'eating', 'writes', 'wrote', 'writen', 'go', 'goes', 'going', 'programming', 'program', 'history', 'finally', 'final', 'congratulate']

# %%
for word in words:
    print(f"word: {word}---> lemmatized: {lemma.lemmatize(word)}")
# Out:
# word: eats---> lemmatized: eats
# word: eaten---> lemmatized: eaten
# word: eating---> lemmatized: eating
# word: writes---> lemmatized: writes
# word: wrote---> lemmatized: wrote
# word: writen---> lemmatized: writen
# word: go---> lemmatized: go
# word: goes---> lemmatized: go
# word: going---> lemmatized: going
# word: programming---> lemmatized: programming
# word: program---> lemmatized: program
# word: history---> lemmatized: history
# word: finally---> lemmatized: finally
# word: final---> lemmatized: final
# word: congratulate---> lemmatized: congratulate
