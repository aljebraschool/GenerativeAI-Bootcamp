# %%
corpus = """
    Hello my name is Ridwan Ibidunni. I am a graduate of mathematics with a keen interest in developing AI applications
    to solve problems in our environments. I love coding and teaching people how to code.
"""

# %%
# %pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in /home/aljebra/.local/lib/python3.10/site-packages (3.9.2)
# Requirement already satisfied: click in /usr/lib/python3/dist-packages (from nltk) (8.1.6)
# Requirement already satisfied: joblib in /home/aljebra/.local/lib/python3.10/site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/aljebra/.local/lib/python3.10/site-packages (from nltk) (2025.11.3)
# Requirement already satisfied: tqdm in /home/aljebra/.local/lib/python3.10/site-packages (from nltk) (4.67.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk

# Download the 'punkt_tab' data package
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/aljebra/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk import sent_tokenize

sentence_tokenized = sent_tokenize(corpus)

# %%
sentence_tokenized
# Out:
# ['\n    Hello my name is Ridwan Ibidunni.',
#  'I am a graduate of mathematics with a keen interest in developing AI applications\n    to solve problems in our environments.',
#  'I love coding and teaching people how to code.']

# %%
sentence_tokenized[0]
# Out:
# '\n    Hello my name is Ridwan Ibidunni.'

# %%
sentence_tokenized[1]
# Out:
# 'I am a graduate of mathematics with a keen interest in developing AI applications\n    to solve problems in our environments.'

# %%
for item in sentence_tokenized:
    print(item)
# Out:
#     Hello my name is Ridwan Ibidunni.
# I am a graduate of mathematics with a keen interest in developing AI applications
#     to solve problems in our environments.
# I love coding and teaching people how to code.

# %%
from nltk import word_tokenize

word = word_tokenize(corpus)

# %%
word
# Out:
# ['Hello',
#  'my',
#  'name',
#  'is',
#  'Ridwan',
#  'Ibidunni',
#  '.',
#  'I',
#  'am',
#  'a',
#  'graduate',
#  'of',
#  'mathematics',
#  'with',
#  'a',
#  'keen',
#  'interest',
#  'in',
#  'developing',
#  'AI',
#  'applications',
#  'to',
#  'solve',
#  'problems',
#  'in',
#  'our',
#  'environments',
#  '.',
#  'I',
#  'love',
#  'coding',
#  'and',
#  'teaching',
#  'people',
#  'how',
#  'to',
#  'code',
#  '.']
